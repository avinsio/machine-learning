# %%
import pandas as pd

# %%
grades = pd.Series([90,80,70,60])

# %%
total = 0
for grade in grades:
    total +=grade
print(total/ len(grades))
# Out:
# 75.0

# %%
import numpy as np
total = sum(grades) / len(grades)
total
# Out:
# 75.0

# %%
numbers =pd.Series(np.random.randint(0,1000,10000))
numbers.head()
# Out:
# 0    447
# 1    282
# 2     82
# 3    787
# 4    234
# dtype: int32

# %%
len(numbers)
# Out:
# 10000

# %% [markdown]
# **Cellular magic function**

# %%
# %%timeit -n 100
total = 0
for number in numbers:
    total += number
total / len(numbers)
# Out:
# 1.27 ms ± 154 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
total = np.sum(numbers)
total / len(numbers)
# Out:
# 42.1 μs ± 13.5 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
numbers.head()
# Out:
# 0    447
# 1    282
# 2     82
# 3    787
# 4    234
# dtype: int32

# %%
numbers +=2
numbers.head()
# Out:
# 0    449
# 1    284
# 2     84
# 3    789
# 4    236
# dtype: int32

# %%
for label, value in numbers.items():
    numbers.iat[label] = value + 2

numbers.head()
# Out:
# 0    451
# 1    286
# 2     86
# 3    791
# 4    238
# dtype: int32

# %%
# %%timeit -n 100
s = pd.Series(np.random.randint(0,1000,1000))
for label, value in s.items():
    s.iat[label] = value + 2
# Out:
# 27.4 ms ± 5.81 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))
s+=2
# Out:
# 250 μs ± 69.4 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
